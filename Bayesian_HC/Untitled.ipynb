# %%
import numpy as np
import pandas as pd
import pymc as pm
import arviz as az
import matplotlib.pyplot as plt
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, ConstantKernel as C

np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import pymc as pm
#       4 import arviz as az
#       5 import matplotlib.pyplot as plt
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pymc/__init__.py:48
#      43     augmented = f"{augmented} -fno-unwind-tables -fno-asynchronous-unwind-tables"
#      45     pytensor.config.gcc__cxxflags = augmented
# ---> 48 __set_compiler_flags()
#      50 from pymc import _version, gp, ode, sampling
#      51 from pymc.backends import *
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pymc/__init__.py:31, in __set_compiler_flags()
#      29 def __set_compiler_flags():
#      30     # Workarounds for PyTensor compiler problems on various platforms
# ---> 31     import pytensor
#      33     current = pytensor.config.gcc__cxxflags
#      34     augmented = f"{current} -Wno-c++11-narrowing"
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/__init__.py:120
#     116     return as_tensor_variable(x, **kwargs)
#     119 # isort: off
# --> 120 from pytensor import scalar, tensor
#     121 from pytensor.compile import (
#     122     In,
#     123     Mode,
#    (...)
#     129     shared,
#     130 )
#     131 from pytensor.compile.function import function, function_dump
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/tensor/__init__.py:103
#      99     return len(var.data)
#     102 import pytensor.tensor.exceptions
# --> 103 import pytensor.tensor.rewriting
#     104 from pytensor.gradient import grad, hessian, jacobian
#     106 # adds shared-variable constructors
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/tensor/rewriting/__init__.py:11
#       9 import pytensor.tensor.rewriting.jax
#      10 import pytensor.tensor.rewriting.linalg
# ---> 11 import pytensor.tensor.rewriting.math
#      12 import pytensor.tensor.rewriting.numba
#      13 import pytensor.tensor.rewriting.ofg
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/tensor/rewriting/math.py:2663
#    2660 get_clients_at_depth2 = partial(get_clients_at_depth, depth=2)
#    2662 # 1+erf(x)=>erfc(-x)
# -> 2663 local_one_plus_erf = PatternNodeRewriter(
#    2664     (add, 1, (erf, "x")),
#    2665     (erfc, (neg, "x")),
#    2666     allow_multiple_clients=True,
#    2667     name="local_one_plus_erf",
#    2668     tracks=[erf],
#    2669     get_nodes=get_clients_at_depth1,
#    2670 )
#    2671 register_canonicalize(local_one_plus_erf)
#    2672 register_stabilize(local_one_plus_erf)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/graph/rewriting/basic.py:1577, in PatternNodeRewriter.__init__(self, in_pattern, out_pattern, allow_multiple_clients, skip_identities_fn, name, tracks, get_nodes, values_eq_approx)
#    1537 def __init__(
#    1538     self,
#    1539     in_pattern,
#    (...)
#    1546     values_eq_approx=None,
#    1547 ):
#    1548     """
#    1549
#    1550     Parameters
#    (...)
#    1575
#    1576     """
# -> 1577     from pytensor.graph.rewriting.unify import convert_strs_to_vars
#    1579     var_map: dict[str, Var] = {}
#    1580     self.in_pattern = convert_strs_to_vars(in_pattern, var_map=var_map)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/p311-env/lib/python3.11/site-packages/pytensor/graph/rewriting/unify.py:17
#      14 from numbers import Number
#      16 import numpy as np
# ---> 17 from cons.core import ConsError, _car, _cdr
#      18 from etuples import apply, etuple, etuplize
#      19 from etuples.core import ExpressionTuple
#
# ModuleNotFoundError: No module named 'cons'
